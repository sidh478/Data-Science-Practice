# %%
# !pip install numpy

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.dropna(axis=1,thresh=800)
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 3, 6, 10, 11, 21, 23, 27, 52, 54, 62, 66, 75, 88, 92, 96, 97, 102, 110, 118, 123, 124, 136, 137, 139, 148, 151, 170, 174, 177, 183, 193, 194, 195, 205, 209, 215, 218, 224, 230, 245, 248, 251, 252, 257, 262, 263, 268, 269, 273, 275, 291, 292, 297, 299, 305, 307, 309, 310, 311, 318, 319, 325, 327, 329, 331, 332, 336, 337, 339, 340, 341, 345, 356, 366, 369, 370, 377, 390, 393, 394, 412, 429, 430, 434, 435, 438, 445, 449, 452, 453, 456, 460, 462, 473, 484, 486, 487, 492, 496, ...]
#
# [183 rows x 0 columns]

# %%
df.dropna(axis=1,how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1,thresh=800,how='all')
# Out:
# Empty DataFrame
# Columns: []
# Index: [1, 3, 6, 10, 11, 21, 23, 27, 52, 54, 62, 66, 75, 88, 92, 96, 97, 102, 110, 118, 123, 124, 136, 137, 139, 148, 151, 170, 174, 177, 183, 193, 194, 195, 205, 209, 215, 218, 224, 230, 245, 248, 251, 252, 257, 262, 263, 268, 269, 273, 275, 291, 292, 297, 299, 305, 307, 309, 310, 311, 318, 319, 325, 327, 329, 331, 332, 336, 337, 339, 340, 341, 345, 356, 366, 369, 370, 377, 390, 393, 394, 412, 429, 430, 434, 435, 438, 445, 449, 452, 453, 456, 460, 462, 473, 484, 486, 487, 492, 496, ...]
#
# [183 rows x 0 columns]

# %%
df.fillna('sidh')
#or
df.fillna(value='sidh')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.fillna(df['Age'].mean())
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby('Survived').describe()['PassengerId'].T
#or
df.groupby('Survived').describe()['PassengerId'].transpose()
# Out:
# Survived           0           1
# count      60.000000  123.000000
# mean      402.983333  480.918699
# std       252.917183  241.058955
# min         7.000000    2.000000
# 25%       174.000000  309.000000
# 50%       359.000000  497.000000
# 75%       634.500000  690.500000
# max       873.000000  890.000000

# %%
df.groupby('Survived').describe()['PassengerId']
# Out:
#           count        mean         std  min    25%    50%    75%    max
# Survived
# 0          60.0  402.983333  252.917183  7.0  174.0  359.0  634.5  873.0
# 1         123.0  480.918699  241.058955  2.0  309.0  497.0  690.5  890.0

# %%
df1=pd.read_csv(r'C:\\users\\harsh\\Downloads\\bank.csv',sep=';')
df1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
l=[]
for i in df1['education'].unique():
    l.append(df1[df1['education']==i])

# %%
df1.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df2=l[0]
df2=df2.head()[['age','job','marital']]
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3=l[1].head(5)
df3=df3[['age','job','marital']]
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
pd.concat([df2,df3])
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced
# 1    33     services   married
# 4    59  blue-collar   married
# 7    39   technician   married
# 10   39     services   married
# 11   43       admin.   married

# %%
#concat means union operation
df5=pd.concat([df2,df3],axis=1)
df5
# Out:
#      age          job   marital   age          job  marital
# 0   30.0   unemployed   married   NaN          NaN      NaN
# 9   43.0     services   married   NaN          NaN      NaN
# 18  25.0  blue-collar    single   NaN          NaN      NaN
# 26  55.0  blue-collar   married   NaN          NaN      NaN
# 36  78.0      retired  divorced   NaN          NaN      NaN
# 1    NaN          NaN       NaN  33.0     services  married
# 4    NaN          NaN       NaN  59.0  blue-collar  married
# 7    NaN          NaN       NaN  39.0   technician  married
# 10   NaN          NaN       NaN  39.0     services  married
# 11   NaN          NaN       NaN  43.0       admin.  married

# %%
df5.iloc[[4,5],[0,3]]
# Out:
#      age   age
# 36  78.0   NaN
# 1    NaN  33.0

# %%
df5.loc[[9,10],['age']]
# Out:
#      age   age
# 9   43.0   NaN
# 10   NaN  39.0

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2.loc[[9,18],['job','marital']]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2.iloc[[1,2],[1,2]]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df3
# Out:
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married

# %%
#consider from inner side set theory(default it is inner)
pd.merge(df2,df3,on='age')
pd.merge(df2,df3,on='age',how='inner')
# Out:
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
#consider from left hand side set theory
pd.merge(df2,df3,on='age',how='left')
# Out:
#    age        job_x marital_x   job_y marital_y
# 0   30   unemployed   married     NaN       NaN
# 1   43     services   married  admin.   married
# 2   25  blue-collar    single     NaN       NaN
# 3   55  blue-collar   married     NaN       NaN
# 4   78      retired  divorced     NaN       NaN

# %%
#consider from right hand side set theory
pd.merge(df2,df3,on='age',how='left')
# Out:
#    age        job_x marital_x   job_y marital_y
# 0   30   unemployed   married     NaN       NaN
# 1   43     services   married  admin.   married
# 2   25  blue-collar    single     NaN       NaN
# 3   55  blue-collar   married     NaN       NaN
# 4   78      retired  divorced     NaN       NaN

# %%
#consider from outer side set theory
pd.merge(df2,df3,on='age',how='outer')
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   30   unemployed   married          NaN       NaN
# 1   43     services   married       admin.   married
# 2   25  blue-collar    single          NaN       NaN
# 3   55  blue-collar   married          NaN       NaN
# 4   78      retired  divorced          NaN       NaN
# 5   33          NaN       NaN     services   married
# 6   59          NaN       NaN  blue-collar   married
# 7   39          NaN       NaN   technician   married
# 8   39          NaN       NaN     services   married

# %%
df2=df2.set_index('age')

# %%
df2.rename(columns={'job':'job1','marital':'marital1'},inplace=True)
df2
# Out:
#             job1  marital1
# age
# 30    unemployed   married
# 43      services   married
# 25   blue-collar    single
# 55   blue-collar   married
# 78       retired  divorced

# %%
df3=df3.set_index('age')
df3
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
df2.join(df3,on='age')
# Out:
#             job1  marital1     job  marital
# age
# 30    unemployed   married     NaN      NaN
# 43      services   married  admin.  married
# 25   blue-collar    single     NaN      NaN
# 55   blue-collar   married     NaN      NaN
# 78       retired  divorced     NaN      NaN

# %%
#for join index value has to be set
#no same column name
df2.join(df3,how='inner')
# Out:
#          job1 marital1     job  marital
# age
# 43   services  married  admin.  married

# %%
pd.merge(df3.reset_index(),df2.reset_index())
# Out:
#    age     job  marital      job1 marital1
# 0   43  admin.  married  services  married

# %% [markdown]
# # dataframe

# %%
df=pd.DataFrame({'col':[1,2,3,4,5],
             'clo2':[45,56,67,34,34],
             'col3':"sudhanshu kumar krish ineuron one".split()
             })
df
# Out:
#    col  clo2       col3
# 0    1    45  sudhanshu
# 1    2    56      kumar
# 2    3    67      krish
# 3    4    34    ineuron
# 4    5    34        one

# %%
df['col4']=df['col']**2
df
# Out:
#    col  clo2       col3  col4
# 0    1    45  sudhanshu     1
# 1    2    56      kumar     4
# 2    3    67      krish     9
# 3    4    34    ineuron    16
# 4    5    34        one    25

# %%
df['col5']=df['col3'].str[0]
df
# Out:
#    col  clo2       col3  col4 col5
# 0    1    45  sudhanshu     1    s
# 1    2    56      kumar     4    k
# 2    3    67      krish     9    k
# 3    4    34    ineuron    16    i
# 4    5    34        one    25    o

# %%
def test(a):
    return a**2

# %%
df['col4_4']=df['col'].apply(test)
df
# Out:
#    col  clo2       col3  col4 col5 col6  col4_4
# 0    1    45  sudhanshu     1    s    s       1
# 1    2    56      kumar     4    k    k       4
# 2    3    67      krish     9    k    k       9
# 3    4    34    ineuron    16    i    i      16
# 4    5    34        one    25    o    o      25

# %%
def test1(a):
    if a=='s':
        return's'
    else:
        return 'z'

# %%
df['col6']=df['col5'].apply(test1)
df
# Out:
#    col  clo2       col3  col4 col5 col6  col4_4
# 0    1    45  sudhanshu     1    s    s       1
# 1    2    56      kumar     4    k    z       4
# 2    3    67      krish     9    k    z       9
# 3    4    34    ineuron    16    i    z      16
# 4    5    34        one    25    o    z      25

# %%
df['col6_6']=df['col5'].apply(lambda a: 's' if a== 's' else 'z')
df
# Out:
#    col  clo2       col3  col4 col5 col6  col4_4 col6_6
# 0    1    45  sudhanshu     1    s    s       1      s
# 1    2    56      kumar     4    k    z       4      z
# 2    3    67      krish     9    k    z       9      z
# 3    4    34    ineuron    16    i    z      16      z
# 4    5    34        one    25    o    z      25      z

# %%
df['col7']=df['col3'].apply(len)
df
# Out:
#    col  clo2       col3  col4 col5 col6  col4_4 col6_6  col7
# 0    1    45  sudhanshu     1    s    s       1      s     9
# 1    2    56      kumar     4    k    z       4      z     5
# 2    3    67      krish     9    k    z       9      z     5
# 3    4    34    ineuron    16    i    z      16      z     7
# 4    5    34        one    25    o    z      25      z     3

# %%
import math
df['col8']=df['clo2'].apply(math.log)
df
# Out:
#    col  clo2       col3  col4 col5 col6  col4_4 col6_6  col7      col8
# 0    1    45  sudhanshu     1    s    s       1      s     9  3.806662
# 1    2    56      kumar     4    k    z       4      z     5  4.025352
# 2    3    67      krish     9    k    z       9      z     5  4.204693
# 3    4    34    ineuron    16    i    z      16      z     7  3.526361
# 4    5    34        one    25    o    z      25      z     3  3.526361
