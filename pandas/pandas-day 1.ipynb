# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(4)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes=="object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes=="object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
l=[4,5,6,7,8,8,9,0,"sidh","kumar"]

# %%
l[0:3]
# Out:
# [4, 5, 6]

# %%
df.dtypes[df.dtypes=="object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df.dtypes.index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
col_name=df.dtypes[df.dtypes=="object"].index

# %%
col_name
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[col_name].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df['ineuron']='sidh'
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked ineuron
# 0        0         A/5 21171   7.2500   NaN        S    sidh
# 1        0          PC 17599  71.2833   C85        C    sidh
# 2        0  STON/O2. 3101282   7.9250   NaN        S    sidh
# 3        0            113803  53.1000  C123        S    sidh
# 4        0            373450   8.0500   NaN        S    sidh
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S    sidh
# 887      0            112053  30.0000   B42        S    sidh
# 888      2        W./C. 6607  23.4500   NaN        S    sidh
# 889      0            111369  30.0000  C148        C    sidh
# 890      0            370376   7.7500   NaN        Q    sidh
#
# [891 rows x 13 columns]

# %%
df[['Name']][0:15]
# Out:
#                                                  Name
# 0                             Braund, Mr. Owen Harris
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                              Heikkinen, Miss. Laina
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                            Allen, Mr. William Henry
# 5                                    Moran, Mr. James
# 6                             McCarthy, Mr. Timothy J
# 7                      Palsson, Master. Gosta Leonard
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                 Nasser, Mrs. Nicholas (Adele Achem)
# 10                    Sandstrom, Miss. Marguerite Rut
# 11                           Bonnell, Miss. Elizabeth
# 12                     Saundercock, Mr. William Henry
# 13                        Andersson, Mr. Anders Johan
# 14               Vestrom, Miss. Hulda Amanda Adolfina

# %%
df[['Name']][0:15:2]
# Out:
#                                                  Name
# 0                             Braund, Mr. Owen Harris
# 2                              Heikkinen, Miss. Laina
# 4                            Allen, Mr. William Henry
# 6                             McCarthy, Mr. Timothy J
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10                    Sandstrom, Miss. Marguerite Rut
# 12                     Saundercock, Mr. William Henry
# 14               Vestrom, Miss. Hulda Amanda Adolfina

# %%
df[df['Age'].isnull()==True]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked ineuron
# 5      male  NaN      0      0      330877   8.4583   NaN        Q    sidh
# 17     male  NaN      0      0      244373  13.0000   NaN        S    sidh
# 19   female  NaN      0      0        2649   7.2250   NaN        C    sidh
# 26     male  NaN      0      0        2631   7.2250   NaN        C    sidh
# 28   female  NaN      0      0      330959   7.8792   NaN        Q    sidh
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C    sidh
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S    sidh
# 868    male  NaN      0      0      345777   9.5000   NaN        S    sidh
# 878    male  NaN      0      0      349217   7.8958   NaN        S    sidh
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S    sidh
#
# [177 rows x 13 columns]

# %%
df[df['Age'].isnull()==True].index
# Out:
# Int64Index([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,
#             ...
#             832, 837, 839, 846, 849, 859, 863, 868, 878, 888],
#            dtype='int64', length=177)

# %%
len(df[df['Age'].isnull()==True].index)
# Out:
# 177

# %%
ind=df[df['Age'].isnull()==True].index

# %%
df.loc[ind]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked ineuron
# 5      male  NaN      0      0      330877   8.4583   NaN        Q    sidh
# 17     male  NaN      0      0      244373  13.0000   NaN        S    sidh
# 19   female  NaN      0      0        2649   7.2250   NaN        C    sidh
# 26     male  NaN      0      0        2631   7.2250   NaN        C    sidh
# 28   female  NaN      0      0      330959   7.8792   NaN        Q    sidh
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C    sidh
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S    sidh
# 868    male  NaN      0      0      345777   9.5000   NaN        S    sidh
# 878    male  NaN      0      0      349217   7.8958   NaN        S    sidh
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S    sidh
#
# [177 rows x 13 columns]

# %%
df['Age'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df[df['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked ineuron
# 5      male  NaN      0      0      330877   8.4583   NaN        Q    sidh
# 17     male  NaN      0      0      244373  13.0000   NaN        S    sidh
# 19   female  NaN      0      0        2649   7.2250   NaN        C    sidh
# 26     male  NaN      0      0        2631   7.2250   NaN        C    sidh
# 28   female  NaN      0      0      330959   7.8792   NaN        Q    sidh
# ..      ...  ...    ...    ...         ...      ...   ...      ...     ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C    sidh
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S    sidh
# 868    male  NaN      0      0      345777   9.5000   NaN        S    sidh
# 878    male  NaN      0      0      349217   7.8958   NaN        S    sidh
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S    sidh
#
# [177 rows x 13 columns]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked ineuron
# 0        0         A/5 21171   7.2500   NaN        S    sidh
# 1        0          PC 17599  71.2833   C85        C    sidh
# 2        0  STON/O2. 3101282   7.9250   NaN        S    sidh
# 3        0            113803  53.1000  C123        S    sidh
# 4        0            373450   8.0500   NaN        S    sidh
# ..     ...               ...      ...   ...      ...     ...
# 886      0            211536  13.0000   NaN        S    sidh
# 887      0            112053  30.0000   B42        S    sidh
# 888      2        W./C. 6607  23.4500   NaN        S    sidh
# 889      0            111369  30.0000  C148        C    sidh
# 890      0            370376   7.7500   NaN        Q    sidh
#
# [891 rows x 13 columns]

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
df['Fare']==max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare']==max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#     ineuron
# 258    sidh
# 679    sidh
# 737    sidh

# %%
df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked ineuron
# 0      0         A/5 21171   7.2500   NaN        S    sidh
# 1      0          PC 17599  71.2833   C85        C    sidh
# 2      0  STON/O2. 3101282   7.9250   NaN        S    sidh
# 3      0            113803  53.1000  C123        S    sidh
# 4      0            373450   8.0500   NaN        S    sidh

# %% [raw]
# 1.Find out how many male and female passenger was onboarded
# 2.how many survied we have
# 3.how many casuality we have(not survied)
# 4.what is name of a person who is the eldest one
# 5.how many passenger do we have in first,second,third class
# 6.how many person we have whose name starts with 's'
# 7.try to create a new column which is a summation of "sibsp" and "prach"
# 8.how many person do we have below age of 25
# 9.how many person died whose age was less then 40
# 10.from a cabin column separate text and numeric value
#
# Read all the resume form ineuron github in pdf,word and try to create a dataframe with resume name as a index avlue,and in column i am expecting email id,linkden id,githun id,skills as result

# %%
#1.Find out how many male and female passenger was onboarded
a=len(df[df["Sex"]=='male'])
b=len(df[df["Sex"]=='female'])
a,b
# Out:
# (577, 314)

# %%
df.groupby('Sex').count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked  ineuron  sidh
# Sex
# female     97       312      314   314
# male      107       577      577   577

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
#2.how many survied we have
df[df['Survived']==1]['Survived'].count()
# Out:
# 342

# %%
len(df[df['Survived']==1])
# Out:
# 342

# %%
#3.how many casuality we have(not survied)
df[df['Survived']==0]['Survived'].count()
# Out:
# 549

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.groupby('Survived').count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked  ineuron
# Survived
# 0            68       549      549
# 1           136       340      342

# %%
#4.what is name of a person who is the eldest one
df[df['Age'] == df['Age'].max()]
df[df['Age'] == max(df['Age'])]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked ineuron
# 630  male  80.0      0      0  27042  30.0   A23        S    sidh

# %%
#5.how many passenger do we have in first,second,third class
df.groupby('Pclass').count()
# Out:
#         PassengerId  Survived  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass
# 1               216       216   216  216  186    216    216     216   216
# 2               184       184   184  184  173    184    184     184   184
# 3               491       491   491  491  355    491    491     491   491
#
#         Cabin  Embarked  ineuron
# Pclass
# 1         176       214      216
# 2          16       184      184
# 3          12       491      491

# %%
df[['Pclass']].value_counts()
# Out:
# Pclass
# 3         491
# 1         216
# 2         184
# dtype: int64

# %%
#6.how many person we have whose name starts with 's'
len(df[df['Name'].str.startswith("S")]['Name'])
# Out:
# 86

# %%
df[df['Name'].str.startswith("S")]['Name'].count()
# Out:
# 86

# %%
#7.try to create a new column which is a summation of "sibsp" and "prach"
df['sidh']=df['SibSp']+df['Parch']
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked ineuron  sidh
# 0        0         A/5 21171   7.2500   NaN        S    sidh     1
# 1        0          PC 17599  71.2833   C85        C    sidh     1
# 2        0  STON/O2. 3101282   7.9250   NaN        S    sidh     0
# 3        0            113803  53.1000  C123        S    sidh     1
# 4        0            373450   8.0500   NaN        S    sidh     0
# ..     ...               ...      ...   ...      ...     ...   ...
# 886      0            211536  13.0000   NaN        S    sidh     0
# 887      0            112053  30.0000   B42        S    sidh     0
# 888      2        W./C. 6607  23.4500   NaN        S    sidh     3
# 889      0            111369  30.0000  C148        C    sidh     0
# 890      0            370376   7.7500   NaN        Q    sidh     0
#
# [891 rows x 14 columns]

# %%
#8.how many person do we have below age of 25
df.groupby(df['Age']<25).count()
# Out:
#        PassengerId  Survived  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  \
# Age
# False          613       613     613   613  613  436    613    613     613
# True           278       278     278   278  278  278    278    278     278
#
#        Fare  Cabin  Embarked  ineuron  sidh
# Age
# False   613    156       611      613   613
# True    278     48       278      278   278

# %%
df[df['Age']<25]['Age'].count()
# Out:
# 278

# %%
#9.how many person died whose age was less then 40
print("not survived:",df[(df['Survived']==0)&(df['Age']<40)]['PassengerId'].count())
# Out:
# not survived: 322

# %%
df[(df['Survived']==0) & (df['Age']<40)].count()
# Out:
# PassengerId    322
# Survived       322
# Pclass         322
# Name           322
# Sex            322
# Age            322
# SibSp          322
# Parch          322
# Ticket         322
# Fare           322
# Cabin           27
# Embarked       322
# ineuron        322
# sidh           322
# dtype: int64

# %%
#10.from a cabin column separate text and numeric value
import re
df['cabin_number']=df['Cabin'].str.replace('([A-Za-z]+)','')
df['cabin_letter']=df['Cabin'].str.extract('([A-Za-z]+)')
df
# Out:
# C:\Users\harsh\AppData\Local\Temp\ipykernel_11704\1852563007.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['cabin_number']=df['Cabin'].str.replace('([A-Za-z]+)','')
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked cabin_number cabin_letter
# 0        0         A/5 21171   7.2500   NaN        S          NaN          NaN
# 1        0          PC 17599  71.2833   C85        C           85            C
# 2        0  STON/O2. 3101282   7.9250   NaN        S          NaN          NaN
# 3        0            113803  53.1000  C123        S          123            C
# 4        0            373450   8.0500   NaN        S          NaN          NaN
# ..     ...               ...      ...   ...      ...          ...          ...
# 886      0            211536  13.0000   NaN        S          NaN          NaN
# 887      0            112053  30.0000   B42        S           42            B
# 888      2        W./C. 6607  23.4500   NaN        S          NaN          NaN
# 889      0            111369  30.0000  C148        C          148            C
# 890      0            370376   7.7500   NaN        Q          NaN          NaN
#
# [891 rows x 14 columns]

# %%
replace=re.compile("([a-zA-z]+)")
df['string_cabin_list']=df['Cabin'].str.extract(replace)
df['num_cabin_list']=df['Cabin'].str.replace(replace,"")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked cabin_number  \
# 0        0         A/5 21171   7.2500   NaN        S          NaN
# 1        0          PC 17599  71.2833   C85        C           85
# 2        0  STON/O2. 3101282   7.9250   NaN        S          NaN
# 3        0            113803  53.1000  C123        S          123
# 4        0            373450   8.0500   NaN        S          NaN
# ..     ...               ...      ...   ...      ...          ...
# 886      0            211536  13.0000   NaN        S          NaN
# 887      0            112053  30.0000   B42        S           42
# 888      2        W./C. 6607  23.4500   NaN        S          NaN
# 889      0            111369  30.0000  C148        C          148
# 890      0            370376   7.7500   NaN        Q          NaN
#
#     cabin_letter string_cabin_list num_cabin_list
# 0            NaN               NaN            NaN
# 1              C                 C             85
# 2            NaN               NaN            NaN
# 3              C                 C            123
# 4            NaN               NaN            NaN
# ..           ...               ...            ...
# 886          NaN               NaN            NaN
# 887            B                 B             42
# 888          NaN               NaN            NaN
# 889            C                 C            148
# 890          NaN               NaN            NaN
#
# [891 rows x 16 columns]

# %%
df=pd.DataFrame(df.Cabin.str.split('([a-zA-z]+)([^a-zA-Z]+)'))
df
# Out:
#             Cabin
# 0             NaN
# 1     [, C, 85, ]
# 2             NaN
# 3    [, C, 123, ]
# 4             NaN
# ..            ...
# 886           NaN
# 887   [, B, 42, ]
# 888           NaN
# 889  [, C, 148, ]
# 890           NaN
#
# [891 rows x 1 columns]

# %%
df['num_cabin_list']
# Out:
# 0      NaN
# 1       85
# 2      NaN
# 3      123
# 4      NaN
#       ...
# 886    NaN
# 887     42
# 888    NaN
# 889    148
# 890    NaN
# Name: num_cabin_list, Length: 891, dtype: object

# %%
df1=pd.read_csv(r'C:\\users\\harsh\\Downloads\\bank.csv',sep=';')
df1.head(10)
# Out:
#    age            job  marital  education default  balance housing loan  \
# 0   30     unemployed  married    primary      no     1787      no   no
# 1   33       services  married  secondary      no     4789     yes  yes
# 2   35     management   single   tertiary      no     1350     yes   no
# 3   30     management  married   tertiary      no     1476     yes  yes
# 4   59    blue-collar  married  secondary      no        0     yes   no
# 5   35     management   single   tertiary      no      747      no   no
# 6   36  self-employed  married   tertiary      no      307     yes   no
# 7   39     technician  married  secondary      no      147     yes   no
# 8   41   entrepreneur  married   tertiary      no      221     yes   no
# 9   43       services  married    primary      no      -88     yes  yes
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no
# 5  cellular   23   feb       141         2    176         3  failure  no
# 6  cellular   14   may       341         1    330         2    other  no
# 7  cellular    6   may       151         2     -1         0  unknown  no
# 8   unknown   14   may        57         2     -1         0  unknown  no
# 9  cellular   17   apr       313         1    147         2  failure  no

# %% [raw]
# 1.how many campaign in this data set
# 2.how many users do we have with housing and personal loan
# 3.how many person do we have whose age is 60+
# 4.in which month we have targeted most of the customer
# 5.which mode of call is giving you more result
# 6.how many entrepreneur do we have in this list
# 7.how many customers do we have with negative balance
# 8.prepare a group of data based on education label

# %%
#1.how many campaign in this data set
len(df1['campaign'].unique())
# Out:
# 32

# %%
len(set(list(df1['campaign'])))
# Out:
# 32

# %%
#2.how many users do we have with housing and personal loan
len(df1[(df1['housing']=='yes')&(df1['loan']=='yes')])
# Out:
# 406

# %%
a=df1[(df1['housing']=='yes')&(df1['loan']=='yes')].count()
a['housing'],a['loan']
# Out:
# (406, 406)

# %%
#3.how many person do we have whose age is 60+
df1.groupby(df1['age']>60).count()
# Out:
#         age   job  marital  education  default  balance  housing  loan  \
# age
# False  4394  4394     4394       4394     4394     4394     4394  4394
# True    127   127      127        127      127      127      127   127
#
#        contact   day  month  duration  campaign  pdays  previous  poutcome  \
# age
# False     4394  4394   4394      4394      4394   4394      4394      4394
# True       127   127    127       127       127    127       127       127
#
#           y
# age
# False  4394
# True    127

# %%
df1[df1['age']>60]['age'].count()
# Out:
# 127

# %%
#4.in which month we have targeted most of the customer
df1['month'].value_counts().index[0]
# Out:
# 'may'

# %%
df1[df1['month']==df1['month']]['month'].value_counts().index[0]
# Out:
# 'may'

# %%
df1['month'].max()
# Out:
# 'sep'

# %%
#5.which mode of call is giving you more result
df_groupby=df1.groupby(['contact','y']).count()
df_groupby
# Out:
#                 age   job  marital  education  default  balance  housing  \
# contact   y
# cellular  no   2480  2480     2480       2480     2480     2480     2480
#           yes   416   416      416        416      416      416      416
# telephone no    257   257      257        257      257      257      257
#           yes    44    44       44         44       44       44       44
# unknown   no   1263  1263     1263       1263     1263     1263     1263
#           yes    61    61       61         61       61       61       61
#
#                loan   day  month  duration  campaign  pdays  previous  \
# contact   y
# cellular  no   2480  2480   2480      2480      2480   2480      2480
#           yes   416   416    416       416       416    416       416
# telephone no    257   257    257       257       257    257       257
#           yes    44    44     44        44        44     44        44
# unknown   no   1263  1263   1263      1263      1263   1263      1263
#           yes    61    61     61        61        61     61        61
#
#                poutcome
# contact   y
# cellular  no       2480
#           yes       416
# telephone no        257
#           yes        44
# unknown   no       1263
#           yes        61

# %%
df_groupby.loc['cellular','yes'][0]
# Out:
# 416

# %%
max(df_groupby.loc['cellular','yes'][0],df_groupby.loc['telephone','yes'][0],df_groupby.loc['unknown','yes'][0])
# Out:
# 416

# %%
#6.how many entrepreneur do we have in this list
df1[df1['job']=='entrepreneur']['job'].count()
# Out:
# 168

# %%
#7.how many customers do we have with negative balance
df1[df1['balance']<0]['balance'].count()
# Out:
# 366

# %%
#8.prepare a group of data based on education label
df1.groupby('education').count()
# Out:
#             age   job  marital  default  balance  housing  loan  contact  \
# education
# primary     678   678      678      678      678      678   678      678
# secondary  2306  2306     2306     2306     2306     2306  2306     2306
# tertiary   1350  1350     1350     1350     1350     1350  1350     1350
# unknown     187   187      187      187      187      187   187      187
#
#             day  month  duration  campaign  pdays  previous  poutcome     y
# education
# primary     678    678       678       678    678       678       678   678
# secondary  2306   2306      2306      2306   2306      2306      2306  2306
# tertiary   1350   1350      1350      1350   1350      1350      1350  1350
# unknown     187    187       187       187    187       187       187   187

# %%
l=[]
for i in df1['education'].unique():
    l.append(df1[df1["education"]==i])

# %%
len(l)
# Out:
# 4

# %%
l[0]
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 0      cellular   19   oct        79         1     -1         0  unknown   no
# 9      cellular   17   apr       313         1    147         2  failure   no
# 18      unknown   23   may       250         1     -1         0  unknown   no
# 26      unknown    5   may       247         1     -1         0  unknown   no
# 36    telephone   22   oct        97         1     -1         0  unknown  yes
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4480   cellular   16   apr       743         1     -1         0  unknown   no
# 4485   cellular   11   may       238         2    361         5  failure   no
# 4486    unknown    9   may       514         1     -1         0  unknown   no
# 4499   cellular   21   nov       362         1     -1         0  unknown   no
# 4503   cellular   29   jul       816         6     -1         0  unknown  yes
#
# [678 rows x 17 columns]

# %%
l[1]
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 1     cellular   11   may       220         1    339         4  failure  no
# 4      unknown    5   may       226         1     -1         0  unknown  no
# 7     cellular    6   may       151         2     -1         0  unknown  no
# 10     unknown   20   may       273         1     -1         0  unknown  no
# 11    cellular   17   apr       113         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4514  cellular   20   apr        45         4    153         1  failure  no
# 4515  cellular    7   jul       624         5     -1         0  unknown  no
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
#
# [2306 rows x 17 columns]

# %%
l[2]
# Out:
#       age            job   marital education default  balance housing loan  \
# 2      35     management    single  tertiary      no     1350     yes   no
# 3      30     management   married  tertiary      no     1476     yes  yes
# 5      35     management    single  tertiary      no      747      no   no
# 6      36  self-employed   married  tertiary      no      307     yes   no
# 8      41   entrepreneur   married  tertiary      no      221     yes   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4501   34     management   married  tertiary      no      297     yes   no
# 4506   42     unemployed  divorced  tertiary      no     -166      no   no
# 4509   51     technician   married  tertiary      no     2506      no   no
# 4517   57  self-employed   married  tertiary     yes    -3313     yes  yes
# 4520   44   entrepreneur    single  tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 2     cellular   16   apr       185         1    330         1  failure  no
# 3      unknown    3   jun       199         4     -1         0  unknown  no
# 5     cellular   23   feb       141         2    176         3  failure  no
# 6     cellular   14   may       341         1    330         2    other  no
# 8      unknown   14   may        57         2     -1         0  unknown  no
# ...        ...  ...   ...       ...       ...    ...       ...      ...  ..
# 4501  cellular   26   aug        63         4     -1         0  unknown  no
# 4506  cellular   29   aug        85         4     -1         0  unknown  no
# 4509  cellular   30   nov       210         3     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4520  cellular    3   apr       345         2    249         7    other  no
#
# [1350 rows x 17 columns]

# %%
l[3]
# Out:
#       age          job   marital education default  balance housing loan  \
# 20     38   management  divorced   unknown      no        0     yes   no
# 27     67      retired   married   unknown      no      696      no   no
# 49     61       admin.   married   unknown      no     4629     yes   no
# 132    43  blue-collar   married   unknown     yes     -715     yes   no
# 133    48       admin.   married   unknown      no        0     yes   no
# ...   ...          ...       ...       ...     ...      ...     ...  ...
# 4337   73      retired   married   unknown      no      519      no   no
# 4342   50  blue-collar   married   unknown      no     2284     yes   no
# 4428   48  blue-collar   married   unknown      no      439     yes   no
# 4471   59   management   married   unknown      no     3534      no   no
# 4508   42       admin.   married   unknown      no      642     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 20     cellular   18   nov        96         2     -1         0  unknown   no
# 27    telephone   17   aug       119         1    105         2  failure   no
# 49     cellular   27   jan       181         1     92         1  success  yes
# 132     unknown   30   may        67         3     -1         0  unknown   no
# 133    cellular    8   may        85         1    168         2  failure   no
# ...         ...  ...   ...       ...       ...    ...       ...      ...  ...
# 4337  telephone   16   oct       434         1     57         1  failure  yes
# 4342  telephone   31   jul      1088        17     -1         0  unknown  yes
# 4428   cellular    2   feb       212         1    249         2    other   no
# 4471   cellular   21   nov       216         4     -1         0  unknown   no
# 4508    unknown   16   may       509         2     -1         0  unknown   no
#
# [187 rows x 17 columns]
